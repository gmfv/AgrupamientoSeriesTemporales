# %%
import math
from math import sqrt, log, floor
from sklearn.metrics import mean_squared_error
from statistics import mean
from fastdtw import fastdtw
from scipy import stats
from scipy.spatial.distance import pdist
 
#Euclidean
def euclidean(x, y):
    r=np.linalg.norm(x-y)
    if math.isnan(r):
        r=1
    #print(r)
    return r

#Fast Dynamic time warping
def fast_DTW(x, y):
    r, _ = fastdtw(x, y, dist=euclidean)
    if math.isnan(r):
        r=1
    #print(r)
    return r

#Spearman
def scorr(x, y):
    r = stats.spearmanr(x, y)[0]
    if math.isnan(r):
        r=0
    #print(r)
    return 1 - r

#RMSE
def rmse(x, y):
    r=sqrt(mean_squared_error(x,y))
    if math.isnan(r):
        r=1
    #print(r)
    return r

def lcs(a, b):  
    lengths = [[0 for j in range(len(b)+1)] for i in range(len(a)+1)]
    # row 0 and column 0 are initialized to 0 already
    for i, x in enumerate(a):
        for j, y in enumerate(b):
            if x == y:
                lengths[i+1][j+1] = lengths[i][j] + 1
            else:
                lengths[i+1][j+1] = max(lengths[i+1][j], lengths[i][j+1])
    x, y = len(a), len(b)
    result = lengths[x][y]
    return result

def discretise(x):
    return int(x * 10)

def multidim_lcs(a, b):
    a = a.applymap(discretise)
    b = b.applymap(discretise)
    rows, dims = a.shape
    lcss = [lcs(a[i+2], b[i+2]) for i in range(dims)]
    return 1 - sum(lcss) / (rows * dims)

#Correlation
def corr(x, y):
    r=np.dot(x-mean(x),y-mean(y))/((np.linalg.norm(x-mean(x)))*(np.linalg.norm(y-mean(y))))
    if math.isnan(r):
        r=0
    #print(r)
    return 1 - r

# %%
from sklearn.preprocessing import LabelEncoder
#from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
import scipy.cluster.hierarchy as hac
from scipy.cluster.hierarchy import fcluster
from sklearn.metrics import silhouette_score, calinski_harabasz_score

DIAMETER_METHODS = ['mean_cluster', 'farthest']
CLUSTER_DISTANCE_METHODS = ['nearest', 'farthest']

def inter_cluster_distances(labels, distances, method='nearest'):
    """Calculates the distances between the two nearest points of each cluster.
    :param labels: a list containing cluster labels for each of the n elements
    :param distances: an n x n numpy.array containing the pairwise distances between elements
    :param method: `nearest` for the distances between the two nearest points in each cluster, or `farthest`
    """
    if method not in CLUSTER_DISTANCE_METHODS:
        raise ValueError(
            'method must be one of {}'.format(CLUSTER_DISTANCE_METHODS))

    if method == 'nearest':
        return __cluster_distances_by_points(labels, distances)
    elif method == 'farthest':
        return __cluster_distances_by_points(labels, distances, farthest=True)


def __cluster_distances_by_points(labels, distances, farthest=False):
    n_unique_labels = len(np.unique(labels))
    cluster_distances = np.full((n_unique_labels, n_unique_labels),
                                float('inf') if not farthest else 0)

    np.fill_diagonal(cluster_distances, 0)

    for i in np.arange(0, len(labels) - 1):
        for ii in np.arange(i, len(labels)):
            if labels[i] != labels[ii] and (
                (not farthest and
                 distances[i, ii] < cluster_distances[labels[i], labels[ii]])
                    or
                (farthest and
                 distances[i, ii] > cluster_distances[labels[i], labels[ii]])):
                cluster_distances[labels[i], labels[ii]] = cluster_distances[
                    labels[ii], labels[i]] = distances[i, ii]
    return cluster_distances


def diameter(labels, distances, method='farthest'):
    """Calculates cluster diameters
    :param labels: a list containing cluster labels for each of the n elements
    :param distances: an n x n numpy.array containing the pairwise distances between elements
    :param method: either `mean_cluster` for the mean distance between all elements in each cluster, or `farthest` for the distance between the two points furthest from each other
    """
    if method not in DIAMETER_METHODS:
        raise ValueError('method must be one of {}'.format(DIAMETER_METHODS))

    n_clusters = len(np.unique(labels))
    diameters = np.zeros(n_clusters)

    if method == 'mean_cluster':
        for i in range(0, len(labels) - 1):
            for ii in range(i + 1, len(labels)):
                if labels[i] == labels[ii]:
                    diameters[labels[i]] += distances[i, ii]

        for i in range(len(diameters)):
            diameters[i] /= sum(labels == i)

    elif method == 'farthest':
        for i in range(0, len(labels) - 1):
            for ii in range(i + 1, len(labels)):
                if labels[i] == labels[ii] and distances[i, ii] > diameters[
                        labels[i]]:
                    diameters[labels[i]] = distances[i, ii]
    return diameters

def dunn(labels, distances, diameter_method='farthest',
         cdist_method='nearest'):
    """
    Dunn index for cluster validation (larger is better).
    
    .. math:: D = \\min_{i = 1 \\ldots n_c; j = i + 1\ldots n_c} \\left\\lbrace \\frac{d \\left( c_i,c_j \\right)}{\\max_{k = 1 \\ldots n_c} \\left(diam \\left(c_k \\right) \\right)} \\right\\rbrace
    
    where :math:`d(c_i,c_j)` represents the distance between
    clusters :math:`c_i` and :math:`c_j`, and :math:`diam(c_k)` is the diameter of cluster :math:`c_k`.
    Inter-cluster distance can be defined in many ways, such as the distance between cluster centroids or between their closest elements. Cluster diameter can be defined as the mean distance between all elements in the cluster, between all elements to the cluster centroid, or as the distance between the two furthest elements.
    The higher the value of the resulting Dunn index, the better the clustering
    result is considered, since higher values indicate that clusters are
    compact (small :math:`diam(c_k)`) and far apart (large :math:`d \\left( c_i,c_j \\right)`).
    :param labels: a list containing cluster labels for each of the n elements
    :param distances: an n x n numpy.array containing the pairwise distances between elements
    :param diameter_method: see :py:function:`diameter` `method` parameter
    :param cdist_method: see :py:function:`diameter` `method` parameter
    
    .. [Kovacs2005] Kovács, F., Legány, C., & Babos, A. (2005). Cluster validity measurement techniques. 6th International Symposium of Hungarian Researchers on Computational Intelligence.
    """

    labels = LabelEncoder().fit(labels).transform(labels)
    
    

    ic_distances = inter_cluster_distances(labels, distances, cdist_method)
    #print("IC",ic_distances)
    if len(ic_distances[ic_distances.nonzero()])==0:
        min_distance = 0
    else:
        min_distance = min(ic_distances[ic_distances.nonzero()])
    max_diameter = max(diameter(labels, distances, diameter_method))
    
    

    return min_distance / max_diameter

# %% [markdown]
# # Distancias

# %%
import pandas as pd
import numpy as np
features = pd.read_csv('FB2_2009al2013.csv', sep=',')

# %%
features = features.iloc[:, 1:]
listadistrito = features.Distrito.values
features = features.drop('Distrito', axis=1)

# %%
features.shape[0]
# Out:
# 200

# %%
lista_excluded = features.columns.tolist()
k=7
n = features.shape[0]

# %%
for mm in list(range(10)):
    KM_EUCLIDEAN=[]
    KM_CORRELATION=[]
    KM_SPEARMAN=[]
    KM_DTW=[]
    for i in list(range(len(features.columns))):
        features2 = features.drop(features.columns[i], axis=1)
        n = features2.shape[0]
        #Euclidean
        f_euclidean_dist = np.zeros((n,n))
        for i in range(0,n):
            #print("i",i)
            for j in range(1,n):
                #print("j",j)
                f_euclidean_dist[i,j] = euclidean(features2.iloc[i].values.flatten(), features2.iloc[j].values.flatten())
        #Corr
        f_corr_dist = np.zeros((n,n))
        for i in range(0,n):
            #print("i",i)
            for j in range(0,n):
               # print("j",j)
                f_corr_dist[i,j] = corr(features2.iloc[i].values.flatten(), features2.iloc[j].values.flatten())

        #scorr
        f_scorr_dist = np.zeros((n,n))
        for i in range(0,n):
            #print("i",i)
            for j in range(0,n):
               # print("j",j)
                f_scorr_dist[i,j] = scorr(features2.iloc[i].values.flatten(), features2.iloc[j].values.flatten())
        #DTW
        f_dtw_dist = np.zeros((n,n))
        for i in range(0,n):
            #print("i",i)
            for j in range(0,n):
                # print("j",j)
                f_dtw_dist[i,j] = fast_DTW(features2.iloc[i].values.flatten(), features2.iloc[j].values.flatten())
        print("--------------K-MEANS------------------")
        #Experimentos K-Means
        km_euc = KMeans(n_clusters=k).fit_predict(f_euclidean_dist)
        print("KM + euclidian distance: ")
        sil = silhouette_score(f_euclidean_dist, km_euc)
        print("SC: ", sil)
        KM_EUCLIDEAN.append(sil)

        km_corr = KMeans(n_clusters=k).fit_predict(f_corr_dist)
        print("KM + corr distance: ")
        sil = silhouette_score(f_corr_dist, km_corr)
        print("SC: ", sil)
        KM_CORRELATION.append(sil)

        km_scorr = KMeans(n_clusters=k).fit_predict(f_scorr_dist)
        print("KM + scorr distance: ")
        sil = silhouette_score(f_scorr_dist, km_scorr)
        print("SC: ", sil)
        KM_SPEARMAN.append(sil)

        km_dtw = KMeans(n_clusters=k).fit_predict(f_dtw_dist)
        print("KM + dtw distance: ")
        sil = silhouette_score(f_dtw_dist, km_dtw)
        print("SC: ", sil)
        KM_DTW.append(sil)
        
    print("Máximo de Euclidean ", np.argmax(KM_EUCLIDEAN))
    print("Máximo de Pearson ", np.argmax(KM_CORRELATION))
    print("Máximo de Spearman ", np.argmax(KM_SPEARMAN))
    print("Máximo de DWT ", np.argmax(KM_DTW))  
    print("ELIMINANDO ", lista_excluded[np.argmax(KM_EUCLIDEAN)])
    del lista_excluded[np.argmax(KM_EUCLIDEAN)]
    max_KM_EUCLIDEAN = max(KM_EUCLIDEAN)
    features = features.drop(features.columns[np.argmax(KM_EUCLIDEAN)], axis = 1)
# Out:
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8315934530369973
# KM + corr distance:
# SC:  0.6623593004545724
# KM + scorr distance:
# SC:  0.65336756533146
# KM + dtw distance:
# SC:  0.8272416549959626
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.40523387963873275
# KM + corr distance:
# SC:  0.5840397304304501
# KM + scorr distance:
# SC:  0.659379113271878
# KM + dtw distance:
# SC:  0.39753091999404605
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319197305959701
# KM + corr distance:
# SC:  0.6367033712717791
# KM + scorr distance:
# SC:  0.6324428581336405
# KM + dtw distance:
# SC:  0.8276476016434549
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.831920773757083
# KM + corr distance:
# SC:  0.6364885981881592
# KM + scorr distance:
# SC:  0.6217880645952418
# KM + dtw distance:
# SC:  0.8276397133250185
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207960493507
# KM + corr distance:
# SC:  0.6410192772978891
# KM + scorr distance:
# SC:  0.620830610526823
# KM + dtw distance:
# SC:  0.8276155626231142
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319202415268123
# KM + corr distance:
# SC:  0.6366730442621744
# KM + scorr distance:
# SC:  0.6594922623191236
# KM + dtw distance:
# SC:  0.8276446622224349
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207955709783
# KM + corr distance:
# SC:  0.6365151938689252
# KM + scorr distance:
# SC:  0.6139091080530673
# KM + dtw distance:
# SC:  0.8276088204757239
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319203952359993
# KM + corr distance:
# SC:  0.6363479013103719
# KM + scorr distance:
# SC:  0.7200081089011138
# KM + dtw distance:
# SC:  0.8276742418289769
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207960003567
# KM + corr distance:
# SC:  0.6366864473839238
# KM + scorr distance:
# SC:  0.6470771591604728
# KM + dtw distance:
# SC:  0.8276183947881692
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319197989730414
# KM + corr distance:
# SC:  0.6365790429972208
# KM + scorr distance:
# SC:  0.631840113128225
# KM + dtw distance:
# SC:  0.8276317462169779
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207960481255
# KM + corr distance:
# SC:  0.636685702708098
# KM + scorr distance:
# SC:  0.6393622505541277
# KM + dtw distance:
# SC:  0.82761360607663
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207960553306
# KM + corr distance:
# SC:  0.6366857257662997
# KM + scorr distance:
# SC:  0.6378649480683287
# KM + dtw distance:
# SC:  0.8276136234788445
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207779412914
# KM + corr distance:
# SC:  0.6365194857678617
# KM + scorr distance:
# SC:  0.6495820300141655
# KM + dtw distance:
# SC:  0.8276215488373723
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207959044084
# KM + corr distance:
# SC:  0.6366861315433782
# KM + scorr distance:
# SC:  0.6257176520122327
# KM + dtw distance:
# SC:  0.8276133540807643
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8317173034209729
# KM + corr distance:
# SC:  0.6805654577692292
# KM + scorr distance:
# SC:  0.6511994200825473
# KM + dtw distance:
# SC:  0.8309802994971949
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.831898953109877
# KM + corr distance:
# SC:  0.6362539607063666
# KM + scorr distance:
# SC:  0.6722115514639537
# KM + dtw distance:
# SC:  0.8278898655145107
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207960553356
# KM + corr distance:
# SC:  0.6366857257675823
# KM + scorr distance:
# SC:  0.6458213558725183
# KM + dtw distance:
# SC:  0.8276127498948194
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207960553356
# KM + corr distance:
# SC:  0.6366857257675823
# KM + scorr distance:
# SC:  0.6458213558725183
# KM + dtw distance:
# SC:  0.8276127498948194
# Máximo de Euclidean  16
# Máximo de Pearson  14
# Máximo de Spearman  7
# Máximo de DWT  14
# ELIMINANDO  KlScore
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8315934530369973
# KM + corr distance:
# SC:  0.6624366078982326
# KM + scorr distance:
# SC:  0.6617853286482794
# KM + dtw distance:
# SC:  0.8272416549959626
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.43938239274014684
# KM + corr distance:
# SC:  0.583183062125419
# KM + scorr distance:
# SC:  0.6634900040231375
# KM + dtw distance:
# SC:  0.3941310215381567
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319197305959701
# KM + corr distance:
# SC:  0.6368234264071322
# KM + scorr distance:
# SC:  0.6366556025747674
# KM + dtw distance:
# SC:  0.8185008512581566
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.831920773757083
# KM + corr distance:
# SC:  0.6363670623204378
# KM + scorr distance:
# SC:  0.6342289800107926
# KM + dtw distance:
# SC:  0.8276397133250185
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207960493507
# KM + corr distance:
# SC:  0.6423355618041627
# KM + scorr distance:
# SC:  0.633740322614986
# KM + dtw distance:
# SC:  0.8276155626231142
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319202415268123
# KM + corr distance:
# SC:  0.6410869505393554
# KM + scorr distance:
# SC:  0.6674336526667918
# KM + dtw distance:
# SC:  0.8276446622224349
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207955709783
# KM + corr distance:
# SC:  0.6362737529587149
# KM + scorr distance:
# SC:  0.626268115081787
# KM + dtw distance:
# SC:  0.8276088204757239
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319203952359993
# KM + corr distance:
# SC:  0.6360192691689717
# KM + scorr distance:
# SC:  0.7238283911764293
# KM + dtw distance:
# SC:  0.8276742418289769
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207960003567
# KM + corr distance:
# SC:  0.6362779898336851
# KM + scorr distance:
# SC:  0.6462353726547435
# KM + dtw distance:
# SC:  0.8276183947881692
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319197989730414
# KM + corr distance:
# SC:  0.6362567743384415
# KM + scorr distance:
# SC:  0.6553138311665877
# KM + dtw distance:
# SC:  0.8276317462169779
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207960481255
# KM + corr distance:
# SC:  0.6362771732262182
# KM + scorr distance:
# SC:  0.6413999828954476
# KM + dtw distance:
# SC:  0.82761360607663
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207960553306
# KM + corr distance:
# SC:  0.6363708252155272
# KM + scorr distance:
# SC:  0.6393823745929054
# KM + dtw distance:
# SC:  0.8276136234788445
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207779412914
# KM + corr distance:
# SC:  0.636368605246783
# KM + scorr distance:
# SC:  0.654506939503402
# KM + dtw distance:
# SC:  0.8276215488373723
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207959044084
# KM + corr distance:
# SC:  0.6363712859395689
# KM + scorr distance:
# SC:  0.632738752295507
# KM + dtw distance:
# SC:  0.8276133540807643
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8317173034209729
# KM + corr distance:
# SC:  0.6803095169267127
# KM + scorr distance:
# SC:  0.6585285585524432
# KM + dtw distance:
# SC:  0.8309802994971949
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.831898953109877
# KM + corr distance:
# SC:  0.6358937265200844
# KM + scorr distance:
# SC:  0.6628777789054177
# KM + dtw distance:
# SC:  0.8278898655145107
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207960553356
# KM + corr distance:
# SC:  0.6363708252168707
# KM + scorr distance:
# SC:  0.6465508244267091
# KM + dtw distance:
# SC:  0.8276127498948194
# Máximo de Euclidean  16
# Máximo de Pearson  14
# Máximo de Spearman  7
# Máximo de DWT  14
# ELIMINANDO  ChangeIdx
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8315934532527194
# KM + corr distance:
# SC:  0.6478549380379264
# KM + scorr distance:
# SC:  0.6636162758831623
# KM + dtw distance:
# SC:  0.8272416549959626
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.4393823927401467
# KM + corr distance:
# SC:  0.5829804475851992
# KM + scorr distance:
# SC:  0.6775862925973795
# KM + dtw distance:
# SC:  0.39652083329744975
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319197305959741
# KM + corr distance:
# SC:  0.6327265405903139
# KM + scorr distance:
# SC:  0.6367136921730845
# KM + dtw distance:
# SC:  0.8276476016434549
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207737570801
# KM + corr distance:
# SC:  0.6359902608066925
# KM + scorr distance:
# SC:  0.6412224754230555
# KM + dtw distance:
# SC:  0.8276397133250185
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207960493503
# KM + corr distance:
# SC:  0.6364627272898528
# KM + scorr distance:
# SC:  0.6383303727746482
# KM + dtw distance:
# SC:  0.8276155626231142
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319202415268129
# KM + corr distance:
# SC:  0.636080047876235
# KM + scorr distance:
# SC:  0.6641619246892067
# KM + dtw distance:
# SC:  0.8276446622224349
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.831920795570973
# KM + corr distance:
# SC:  0.6359900972338915
# KM + scorr distance:
# SC:  0.63064662820973
# KM + dtw distance:
# SC:  0.8276088204757239
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319203952359905
# KM + corr distance:
# SC:  0.6355189861854432
# KM + scorr distance:
# SC:  0.7034542759993712
# KM + dtw distance:
# SC:  0.8276742418289769
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207960003605
# KM + corr distance:
# SC:  0.6359943569646451
# KM + scorr distance:
# SC:  0.6401773416054262
# KM + dtw distance:
# SC:  0.8184719234124685
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319197989730434
# KM + corr distance:
# SC:  0.640350424952636
# KM + scorr distance:
# SC:  0.6607220611328642
# KM + dtw distance:
# SC:  0.8276317462169779
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207960481191
# KM + corr distance:
# SC:  0.635993521677836
# KM + scorr distance:
# SC:  0.6442717005591134
# KM + dtw distance:
# SC:  0.82761360607663
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.831920796055325
# KM + corr distance:
# SC:  0.6364633494692382
# KM + scorr distance:
# SC:  0.6307130387346143
# KM + dtw distance:
# SC:  0.8276136234788445
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207779412926
# KM + corr distance:
# SC:  0.636414922405943
# KM + scorr distance:
# SC:  0.6588438139719315
# KM + dtw distance:
# SC:  0.8276215488373723
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207959044118
# KM + corr distance:
# SC:  0.6358949710445095
# KM + scorr distance:
# SC:  0.6346753319579684
# KM + dtw distance:
# SC:  0.8276133540807643
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8317173034209625
# KM + corr distance:
# SC:  0.679991799430851
# KM + scorr distance:
# SC:  0.6585950439368721
# KM + dtw distance:
# SC:  0.8309803010472433
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8318989531098729
# KM + corr distance:
# SC:  0.6353845042465234
# KM + scorr distance:
# SC:  0.6528835458376654
# KM + dtw distance:
# SC:  0.8278898655145107
# Máximo de Euclidean  11
# Máximo de Pearson  14
# Máximo de Spearman  7
# Máximo de DWT  14
# ELIMINANDO  Spikiness
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8315934532527194
# KM + corr distance:
# SC:  0.6527582159283364
# KM + scorr distance:
# SC:  0.6521985294783526
# KM + dtw distance:
# SC:  0.82724154795734
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.4393823927401467
# KM + corr distance:
# SC:  0.5810962841096027
# KM + scorr distance:
# SC:  0.6910478279243264
# KM + dtw distance:
# SC:  0.39303177439816894
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319197305959741
# KM + corr distance:
# SC:  0.6355551178236528
# KM + scorr distance:
# SC:  0.6390410619747474
# KM + dtw distance:
# SC:  0.8276475158340708
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207737570801
# KM + corr distance:
# SC:  0.6354259056347624
# KM + scorr distance:
# SC:  0.6271315417428105
# KM + dtw distance:
# SC:  0.8276396244243839
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207960493503
# KM + corr distance:
# SC:  0.6359495976877444
# KM + scorr distance:
# SC:  0.6232617027648346
# KM + dtw distance:
# SC:  0.8276154800496375
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319202415268129
# KM + corr distance:
# SC:  0.6356277387997984
# KM + scorr distance:
# SC:  0.6618121255952342
# KM + dtw distance:
# SC:  0.8276445560403616
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.831920795570973
# KM + corr distance:
# SC:  0.6288726045526883
# KM + scorr distance:
# SC:  0.6167958882806468
# KM + dtw distance:
# SC:  0.8276088053676023
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319203952359905
# KM + corr distance:
# SC:  0.6320372542197885
# KM + scorr distance:
# SC:  0.6930851042717027
# KM + dtw distance:
# SC:  0.8276742294881194
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207960003605
# KM + corr distance:
# SC:  0.6355361345577112
# KM + scorr distance:
# SC:  0.6080863499692462
# KM + dtw distance:
# SC:  0.8276187595685431
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319197989730434
# KM + corr distance:
# SC:  0.6354031094540222
# KM + scorr distance:
# SC:  0.6739248356514657
# KM + dtw distance:
# SC:  0.8276319053780107
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207960481191
# KM + corr distance:
# SC:  0.6359499298668116
# KM + scorr distance:
# SC:  0.6266268065663004
# KM + dtw distance:
# SC:  0.8276138858126234
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207779412926
# KM + corr distance:
# SC:  0.6355335376122528
# KM + scorr distance:
# SC:  0.634882719070571
# KM + dtw distance:
# SC:  0.8276215017306957
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207959044118
# KM + corr distance:
# SC:  0.6354280842835992
# KM + scorr distance:
# SC:  0.6133994116643354
# KM + dtw distance:
# SC:  0.827614303109176
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8317173034209625
# KM + corr distance:
# SC:  0.6795915403202648
# KM + scorr distance:
# SC:  0.6459970334336441
# KM + dtw distance:
# SC:  0.8309807788268528
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8318989531098729
# KM + corr distance:
# SC:  0.6349481228973642
# KM + scorr distance:
# SC:  0.665592593311908
# KM + dtw distance:
# SC:  0.827890710604918
# Máximo de Euclidean  4
# Máximo de Pearson  13
# Máximo de Spearman  7
# Máximo de DWT  13
# ELIMINANDO  Linearity
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8315934530455453
# KM + corr distance:
# SC:  0.6604004837083599
# KM + scorr distance:
# SC:  0.6475684782644368
# KM + dtw distance:
# SC:  0.8272421787402624
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.3870091685290997
# KM + corr distance:
# SC:  0.5786629489535149
# KM + scorr distance:
# SC:  0.6798977882097266
# KM + dtw distance:
# SC:  0.3921279669765494
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319197305899598
# KM + corr distance:
# SC:  0.6348771001921091
# KM + scorr distance:
# SC:  0.5962377369450731
# KM + dtw distance:
# SC:  0.8276485493052715
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207737511082
# KM + corr distance:
# SC:  0.6348508166667461
# KM + scorr distance:
# SC:  0.6205037586098342
# KM + dtw distance:
# SC:  0.8276347575134492
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319202415208292
# KM + corr distance:
# SC:  0.6350664047139366
# KM + scorr distance:
# SC:  0.6479854261081838
# KM + dtw distance:
# SC:  0.8276565133131841
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207955650387
# KM + corr distance:
# SC:  0.634847175052574
# KM + scorr distance:
# SC:  0.6001976142071712
# KM + dtw distance:
# SC:  0.8276187008008784
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319203952300223
# KM + corr distance:
# SC:  0.6345662115295417
# KM + scorr distance:
# SC:  0.6758983860569839
# KM + dtw distance:
# SC:  0.8276864277595373
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207959944278
# KM + corr distance:
# SC:  0.6349701326324443
# KM + scorr distance:
# SC:  0.5993649273649325
# KM + dtw distance:
# SC:  0.8276313237931961
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319197989670214
# KM + corr distance:
# SC:  0.6361846462026273
# KM + scorr distance:
# SC:  0.6896837367964429
# KM + dtw distance:
# SC:  0.8276317789839073
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.831920796042152
# KM + corr distance:
# SC:  0.6349691789899108
# KM + scorr distance:
# SC:  0.6029083906369553
# KM + dtw distance:
# SC:  0.8276159701183095
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207779353391
# KM + corr distance:
# SC:  0.6349677329870355
# KM + scorr distance:
# SC:  0.6117503187186085
# KM + dtw distance:
# SC:  0.8276247270300442
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207958984767
# KM + corr distance:
# SC:  0.6348519206070324
# KM + scorr distance:
# SC:  0.583403454426907
# KM + dtw distance:
# SC:  0.8276165210489449
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8317173034020526
# KM + corr distance:
# SC:  0.6790836500391744
# KM + scorr distance:
# SC:  0.6426863804358913
# KM + dtw distance:
# SC:  0.8309818088906766
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8318989531036078
# KM + corr distance:
# SC:  0.6343076901058949
# KM + scorr distance:
# SC:  0.6570042794579817
# KM + dtw distance:
# SC:  0.8278924953161585
# Máximo de Euclidean  9
# Máximo de Pearson  12
# Máximo de Spearman  8
# Máximo de DWT  12
# ELIMINANDO  Lumpiness
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8315934529390713
# KM + corr distance:
# SC:  0.662814217077864
# KM + scorr distance:
# SC:  0.6363008895867844
# KM + dtw distance:
# SC:  0.8272420908886187
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.439382392292117
# KM + corr distance:
# SC:  0.5819603863342043
# KM + scorr distance:
# SC:  0.6933891554776447
# KM + dtw distance:
# SC:  0.3955794390133157
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319197305827237
# KM + corr distance:
# SC:  0.6342644063974777
# KM + scorr distance:
# SC:  0.6365981484821923
# KM + dtw distance:
# SC:  0.8276486033137195
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207737439376
# KM + corr distance:
# SC:  0.6342428291831387
# KM + scorr distance:
# SC:  0.6100043596633249
# KM + dtw distance:
# SC:  0.8276349842700439
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.831920241513595
# KM + corr distance:
# SC:  0.6343479079353284
# KM + scorr distance:
# SC:  0.6269609301854279
# KM + dtw distance:
# SC:  0.8276568449976405
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207955578033
# KM + corr distance:
# SC:  0.6341234570184853
# KM + scorr distance:
# SC:  0.5620424709771278
# KM + dtw distance:
# SC:  0.8276182821177094
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319203952228343
# KM + corr distance:
# SC:  0.6338274313716703
# KM + scorr distance:
# SC:  0.6539869527001432
# KM + dtw distance:
# SC:  0.8276857348528799
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207959872381
# KM + corr distance:
# SC:  0.6321952364627083
# KM + scorr distance:
# SC:  0.5707111111057507
# KM + dtw distance:
# SC:  0.827630085095486
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319197989598479
# KM + corr distance:
# SC:  0.6320220966441746
# KM + scorr distance:
# SC:  0.697579074713989
# KM + dtw distance:
# SC:  0.8276318506380165
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207779281416
# KM + corr distance:
# SC:  0.6321967299454212
# KM + scorr distance:
# SC:  0.6009329915228855
# KM + dtw distance:
# SC:  0.8276242105181284
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207958912562
# KM + corr distance:
# SC:  0.628314192769967
# KM + scorr distance:
# SC:  0.58352531197094
# KM + dtw distance:
# SC:  0.8276150672795382
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8317173033913062
# KM + corr distance:
# SC:  0.6784194432431832
# KM + scorr distance:
# SC:  0.6303752331515198
# KM + dtw distance:
# SC:  0.8309821761683495
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8318989530961357
# KM + corr distance:
# SC:  0.6335104536075175
# KM + scorr distance:
# SC:  0.6510067682131213
# KM + dtw distance:
# SC:  0.8278929778521489
# Máximo de Euclidean  7
# Máximo de Pearson  11
# Máximo de Spearman  8
# Máximo de DWT  11
# ELIMINANDO  Trough
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.831593453147187
# KM + corr distance:
# SC:  0.6495590259780453
# KM + scorr distance:
# SC:  0.6126856106893902
# KM + dtw distance:
# SC:  0.8272483205561055
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.4393823905772708
# KM + corr distance:
# SC:  0.5813573601782865
# KM + scorr distance:
# SC:  0.7065369188636416
# KM + dtw distance:
# SC:  0.39657129918337797
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319197305275168
# KM + corr distance:
# SC:  0.6360519309907385
# KM + scorr distance:
# SC:  0.6310344883112009
# KM + dtw distance:
# SC:  0.827668257634522
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207736890141
# KM + corr distance:
# SC:  0.6326493106978106
# KM + scorr distance:
# SC:  0.6053190550452167
# KM + dtw distance:
# SC:  0.827637043015035
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319202414586137
# KM + corr distance:
# SC:  0.6333118394032291
# KM + scorr distance:
# SC:  0.6205284231925207
# KM + dtw distance:
# SC:  0.8276689705888525
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207955029044
# KM + corr distance:
# SC:  0.6360483145009355
# KM + scorr distance:
# SC:  0.536722426400171
# KM + dtw distance:
# SC:  0.8276288752820321
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319203951678198
# KM + corr distance:
# SC:  0.632876908498724
# KM + scorr distance:
# SC:  0.6104024826017621
# KM + dtw distance:
# SC:  0.827688806499689
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.831919798904839
# KM + corr distance:
# SC:  0.6331346176413659
# KM + scorr distance:
# SC:  0.681142305880877
# KM + dtw distance:
# SC:  0.827631062972836
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207778731783
# KM + corr distance:
# SC:  0.6302063644527253
# KM + scorr distance:
# SC:  0.5623329504919613
# KM + dtw distance:
# SC:  0.827638641676063
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207958363095
# KM + corr distance:
# SC:  0.6330913639515336
# KM + scorr distance:
# SC:  0.5483828501218748
# KM + dtw distance:
# SC:  0.8276162618748498
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8317173032811511
# KM + corr distance:
# SC:  0.6787247938569436
# KM + scorr distance:
# SC:  0.5982053903481256
# KM + dtw distance:
# SC:  0.8309926729137515
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8318989530372407
# KM + corr distance:
# SC:  0.632497673393861
# KM + scorr distance:
# SC:  0.6446598083317043
# KM + dtw distance:
# SC:  0.8279066123597031
# Máximo de Euclidean  9
# Máximo de Pearson  10
# Máximo de Spearman  1
# Máximo de DWT  10
# ELIMINANDO  Vchange
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8315934530052027
# KM + corr distance:
# SC:  0.6518787040949963
# KM + scorr distance:
# SC:  0.5500853743109699
# KM + dtw distance:
# SC:  0.8272397252583954
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.4532783552168658
# KM + corr distance:
# SC:  0.5766853021152485
# KM + scorr distance:
# SC:  0.6644507970680735
# KM + dtw distance:
# SC:  0.39152652526122106
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319197303765818
# KM + corr distance:
# SC:  0.6357982486604159
# KM + scorr distance:
# SC:  0.5569387507694511
# KM + dtw distance:
# SC:  0.8276518658177303
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207735380755
# KM + corr distance:
# SC:  0.6357512807262957
# KM + scorr distance:
# SC:  0.5522923583304487
# KM + dtw distance:
# SC:  0.8276348513164226
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319202413076647
# KM + corr distance:
# SC:  0.636053188319268
# KM + scorr distance:
# SC:  0.583628245037105
# KM + dtw distance:
# SC:  0.8276542426268259
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207953519792
# KM + corr distance:
# SC:  0.631955270425301
# KM + scorr distance:
# SC:  0.4799184143623388
# KM + dtw distance:
# SC:  0.827616680278237
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319203950162142
# KM + corr distance:
# SC:  0.6316148029075235
# KM + scorr distance:
# SC:  0.5518865998637648
# KM + dtw distance:
# SC:  0.8276825603118846
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319197987538536
# KM + corr distance:
# SC:  0.6355983375108228
# KM + scorr distance:
# SC:  0.6422302544082634
# KM + dtw distance:
# SC:  0.8276230377096787
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207777221816
# KM + corr distance:
# SC:  0.6320730863158159
# KM + scorr distance:
# SC:  0.5101991477239175
# KM + dtw distance:
# SC:  0.8276091508675915
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8317173029161061
# KM + corr distance:
# SC:  0.6740796925713234
# KM + scorr distance:
# SC:  0.5540134715610616
# KM + dtw distance:
# SC:  0.8309816984735832
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.831898952877201
# KM + corr distance:
# SC:  0.633936375617263
# KM + scorr distance:
# SC:  0.6044502676251654
# KM + dtw distance:
# SC:  0.8278933372991557
# Máximo de Euclidean  5
# Máximo de Pearson  9
# Máximo de Spearman  1
# Máximo de DWT  9
# ELIMINANDO  Season
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.831593452415209
# KM + corr distance:
# SC:  0.6542895654209565
# KM + scorr distance:
# SC:  0.4920482616088469
# KM + dtw distance:
# SC:  0.8272428524453312
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.40089181291942816
# KM + corr distance:
# SC:  0.5780878857611111
# KM + scorr distance:
# SC:  0.5392924138586271
# KM + dtw distance:
# SC:  0.39294145010010567
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319197298904691
# KM + corr distance:
# SC:  0.6264249410332297
# KM + scorr distance:
# SC:  0.516754481565225
# KM + dtw distance:
# SC:  0.8276496576321344
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207730537073
# KM + corr distance:
# SC:  0.6303763092969021
# KM + scorr distance:
# SC:  0.48930270013378746
# KM + dtw distance:
# SC:  0.8276269007329289
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.83192024082306
# KM + corr distance:
# SC:  0.6356967302101185
# KM + scorr distance:
# SC:  0.5054264372567246
# KM + dtw distance:
# SC:  0.8276625637741207
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.831920394530983
# KM + corr distance:
# SC:  0.6259122226271734
# KM + scorr distance:
# SC:  0.47362215046501605
# KM + dtw distance:
# SC:  0.8276871558498786
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319197982682814
# KM + corr distance:
# SC:  0.6351800755285486
# KM + scorr distance:
# SC:  0.5834466327827156
# KM + dtw distance:
# SC:  0.8276285632743193
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.831920777237872
# KM + corr distance:
# SC:  0.6308510553547739
# KM + scorr distance:
# SC:  0.4268155151288894
# KM + dtw distance:
# SC:  0.8276050168546729
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8317173018974554
# KM + corr distance:
# SC:  0.6785069256008142
# KM + scorr distance:
# SC:  0.5005331500275894
# KM + dtw distance:
# SC:  0.8309830075004574
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8318989523664468
# KM + corr distance:
# SC:  0.6293353137533826
# KM + scorr distance:
# SC:  0.5062975507034863
# KM + dtw distance:
# SC:  0.8278932451604204
# Máximo de Euclidean  7
# Máximo de Pearson  8
# Máximo de Spearman  6
# Máximo de DWT  8
# ELIMINANDO  Lshift
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.831593434886178
# KM + corr distance:
# SC:  0.654828214626362
# KM + scorr distance:
# SC:  0.4616829062194443
# KM + dtw distance:
# SC:  0.8272439424340632
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.43937936209538264
# KM + corr distance:
# SC:  0.5777365150531408
# KM + scorr distance:
# SC:  0.4875434876247537
# KM + dtw distance:
# SC:  0.3844083279751389
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319197117713089
# KM + corr distance:
# SC:  0.6304386023877221
# KM + scorr distance:
# SC:  0.5022514669480745
# KM + dtw distance:
# SC:  0.8276330270566014
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319207549392479
# KM + corr distance:
# SC:  0.6347367598225511
# KM + scorr distance:
# SC:  0.47468192980818213
# KM + dtw distance:
# SC:  0.8276300187725087
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.831920222704482
# KM + corr distance:
# SC:  0.6351232634303683
# KM + scorr distance:
# SC:  0.4934111140539345
# KM + dtw distance:
# SC:  0.8276450347057787
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319203763553312
# KM + corr distance:
# SC:  0.6341385179305249
# KM + scorr distance:
# SC:  0.5819813378788702
# KM + dtw distance:
# SC:  0.8276852085239716
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8319197801458995
# KM + corr distance:
# SC:  0.6296368337051615
# KM + scorr distance:
# SC:  0.5944563044703014
# KM + dtw distance:
# SC:  0.8276219039880115
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8317172586676647
# KM + corr distance:
# SC:  0.6757683949508523
# KM + scorr distance:
# SC:  0.4915095424249134
# KM + dtw distance:
# SC:  0.830979393556502
# --------------K-MEANS------------------
# KM + euclidian distance:
# SC:  0.8318989333385463
# KM + corr distance:
# SC:  0.6234170216850211
# KM + scorr distance:
# SC:  0.5104043748651578
# KM + dtw distance:
# SC:  0.8278816574710247
# Máximo de Euclidean  3
# Máximo de Pearson  7
# Máximo de Spearman  6
# Máximo de DWT  7
# ELIMINANDO  Trend

# %%
import csv

with open('SeleccionadosPorEliminacionKMEANS', 'w') as f:
      
    # using csv.writer method from CSV package
    write = csv.writer(f)
      
    write.writerow(lista_excluded)

# %%
features
# Out:
#           Mean           Var          ACF1  Curvature          Peak  \
# 0     6.904494  5.239362e+01  8.135193e-01  -0.863262  1.000000e+00
# 1    44.781615  4.841265e+03  9.371226e-01   0.391511  1.000000e-07
# 2    44.819130  1.042302e+04  9.285754e-01  -0.361289  1.000000e-07
# 3    18.306891  8.273701e+02  7.051710e-01  -0.677443  1.000000e+00
# 4    59.676847  1.191727e+04  9.103049e-01  -0.154082  1.000000e-07
# ..         ...           ...           ...        ...           ...
# 195  33.333333  1.000000e-07  1.000000e-08  -0.016121  1.000000e-07
# 196  27.129680  1.000000e-07  1.000000e-08  -0.016121  1.000000e-07
# 197  23.540490  1.000000e-07  1.000000e-08  -0.144232  1.000000e-07
# 198  56.497175  1.000000e-07  1.000000e-08  -0.016121  1.000000e-07
# 199  10.999890  1.000000e-07  1.000000e-08  -0.016121  1.000000e-07
#
#           Entropy  Fspots  Cpoints
# 0    5.978370e-01   172.0      6.0
# 1    1.698908e-01    49.0     10.0
# 2    1.317796e-01    58.0      2.0
# 3    5.381565e-01   120.0      3.0
# 4    1.524750e-01    84.0      4.0
# ..            ...     ...      ...
# 195  1.000000e-08   193.0      0.0
# 196  1.000000e-08   193.0      0.0
# 197  1.000000e-08   191.0      1.0
# 198  1.000000e-08   193.0      0.0
# 199  1.000000e-08   193.0      0.0
#
# [200 rows x 8 columns]
