# %% [markdown]
# # 18 atributos VS 8 atributos

# %%
import pandas as pd
import os

my_path = os.path.abspath('')
my_path = my_path.split('\\')
my_path_py = "\\".join(my_path[:-1])

# %%
F8_FS = pd.read_csv('Scores_FeatureSelection_F8K5.csv', sep=',')
F8_FS
# Out:
#                 Metrica  SIL HAC 8  SIL KM 8  SIL DB 8    CHZ HAC 8  \
# 0    Euclidean Distance   0.836812  0.861429  0.446337  2228.434952
# 1   Pearson Correlation   0.652477  0.664662  0.377648  1670.392174
# 2  Spearman Correlation   0.431840  0.433442  0.715602   152.175631
# 3  Dynamic Time Warping   0.834470  0.859425 -0.124477  2202.823020
#
#       CHZ KM 8    CHZ DB 8  DAVIES HAC 8  DAVIES KM 8  DAVIES DB 8
# 0  2612.301189    9.566139      0.392022     0.310596     1.066877
# 1  1902.229235  485.212506      0.458880     0.478311     0.484933
# 2   155.267459   45.618818      0.826878     0.872578     1.007251
# 3  2577.484954    2.667479      0.392041     0.311323     1.421516

# %%
TODO_SIL = pd.read_csv(my_path_py+'\\2_FeatureBased\\Scores1_FeatureBased_K5.csv', sep=',')
TODO_SIL
# Out:
#                 METRICA  SIL - HAC  SIL - KM  SIL - DB    CHZ - HAC  \
# 0    Euclidean Distance   0.836812  0.861429  0.446337  2228.435024
# 1   Pearson Correlation   0.632163  0.665757 -0.126499  1582.112815
# 2  Spearman Correlation   0.613085  0.593719  0.635183   335.126053
# 3  Dynamic Time Warping   0.834460  0.856574  0.376788  2202.816138
#
#       CHZ - KM    CHZ - DB  DUNN - HAC  DUNN - KM  DUNN - DB  DAVID - HAC  \
# 0  2612.301411    9.566139    0.694011   0.810553   0.001843     0.392022
# 1  1867.779633    0.852401    5.039795   5.039795   0.928691     0.477132
# 2   346.660645  185.222451    0.000000   0.000000   0.000000     0.559364
# 3  2574.902451   11.921032    0.697935   0.823479   0.003737     0.392042
#
#    DAVID - KM  DAVID - DB
# 0    0.310596    1.066877
# 1    0.472617    1.023568
# 2    0.762185    0.377073
# 3    0.319688    1.217600

# %% [markdown]
# # SILHOUETTE SCORE

# %%
compara = pd.DataFrame()
compara['Metrica'] = F8_FS['Metrica']

compara['HAC All Features'] = TODO_SIL['SIL - HAC'] 
compara['HAC 8F'] = F8_FS['SIL HAC 8']

compara['KM All Features'] = TODO_SIL['SIL - KM'] 
compara['KM 8F'] = F8_FS['SIL KM 8']

compara['DBS All Features'] = TODO_SIL['SIL - DB'] 
compara['DBS 8F'] = F8_FS['SIL DB 8']


compara
# Out:
#                 Metrica  HAC All Features    HAC 8F  KM All Features  \
# 0    Euclidean Distance          0.836812  0.836812         0.861429
# 1   Pearson Correlation          0.632163  0.652477         0.665757
# 2  Spearman Correlation          0.613085  0.431840         0.593719
# 3  Dynamic Time Warping          0.834460  0.834470         0.856574
#
#       KM 8F  DBS All Features    DBS 8F
# 0  0.861429          0.446337  0.446337
# 1  0.664662         -0.126499  0.377648
# 2  0.433442          0.635183  0.715602
# 3  0.859425          0.376788 -0.124477

# %% [markdown]
# # CALINSKI HARAZS

# %%
compara2 = pd.DataFrame()
compara2['Metrica'] = F8_FS['Metrica']

compara2['HAC All Features'] = TODO_SIL['CHZ - HAC'] 
compara2['HAC 8F'] = F8_FS['CHZ HAC 8']

compara2['KM All Features'] = TODO_SIL['CHZ - KM'] 
compara2['KM 8F'] = F8_FS['CHZ KM 8']

compara2['DBS All Features'] = TODO_SIL['CHZ - DB'] 
compara2['DBS 8F'] = F8_FS['CHZ DB 8']


compara2
# Out:
#                 Metrica  HAC All Features       HAC 8F  KM All Features  \
# 0    Euclidean Distance       2228.435024  2228.434952      2612.301411
# 1   Pearson Correlation       1582.112815  1670.392174      1867.779633
# 2  Spearman Correlation        335.126053   152.175631       346.660645
# 3  Dynamic Time Warping       2202.816138  2202.823020      2574.902451
#
#          KM 8F  DBS All Features      DBS 8F
# 0  2612.301189          9.566139    9.566139
# 1  1902.229235          0.852401  485.212506
# 2   155.267459        185.222451   45.618818
# 3  2577.484954         11.921032    2.667479

# %%
compara3 = pd.DataFrame()
compara3['Metrica'] = F8_FS['Metrica']

compara3['HAC All Features'] = TODO_SIL['DAVID - HAC'] 
compara3['HAC 8F'] = F8_FS['DAVIES HAC 8']

compara3['KM All Features'] = TODO_SIL['DAVID - KM'] 
compara3['KM 8F'] = F8_FS['DAVIES KM 8']

compara3['DBS All Features'] = TODO_SIL['DAVID - DB'] 
compara3['DBS 8F'] = F8_FS['DAVIES DB 8']


compara3
# Out:
#                 Metrica  HAC All Features    HAC 8F  KM All Features  \
# 0    Euclidean Distance          0.392022  0.392022         0.310596
# 1   Pearson Correlation          0.477132  0.458880         0.472617
# 2  Spearman Correlation          0.559364  0.826878         0.762185
# 3  Dynamic Time Warping          0.392042  0.392041         0.319688
#
#       KM 8F  DBS All Features    DBS 8F
# 0  0.310596          1.066877  1.066877
# 1  0.478311          1.023568  0.484933
# 2  0.872578          0.377073  1.007251
# 3  0.311323          1.217600  1.421516
