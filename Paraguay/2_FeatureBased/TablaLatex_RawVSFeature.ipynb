# %%
import pandas as pd
import os
my_path = os.path.abspath('')
my_path = my_path.split('\\')
my_path_py = "\\".join(my_path[:-1])

# %%
df = pd.read_csv(my_path_py+ '\\1_RawBased\\RawBased_2009to2013.csv', sep=',')
#df = df.drop(columns=['Unnamed: 0'])
dff = pd.read_csv(my_path_py+ '\\2_FeatureBased\\Scores1_FeatureBasedK6.csv', sep=',')
#dff = dff.drop(columns=['Unnamed: 0'])
df_f1 =  pd.read_csv('Scores1_FeatureBased09-10-11.csv', sep=',')
df_f1 = df_f1.drop(columns=['Unnamed: 0'])
df_f2 =  pd.read_csv('Scores1_FeatureBased12-13.csv', sep=',')
df_f2 = df_f2.drop(columns=['Unnamed: 0'])

# %%
df1= pd.DataFrame()
lista1 = []
lista2 = []
#Definición de 1ra Columna
for i in list(range(4)):
    lista1.append('Jerárquico Aglomerativo')
for i in list(range(4)):
    lista1.append('K-means')
for i in list(range(4)):
    lista1.append('DBScan')   
    
#Definición de 2da Columna
for i in list(range(3)):
    lista2.append('Distancia Euclideana')
    lista2.append('Correlación Pearson')
    lista2.append('Correlación Spearman')
    lista2.append('Dynamic Time Warping')

#Agrupamiento de columnas para la tabla
df1['Algoritmo de agrupamiento'] = lista1
df1['Métrica de similaridad'] = lista2

lista3 = []

#Definición de 3ra Columna
for i in list(range(3)):
    lista3.append(df.iloc[0,i+1])
    lista3.append(df.iloc[1,i+1])
    lista3.append(df.iloc[2,i+1])
    lista3.append(df.iloc[3,i+1])
df1['Puntaje Silhouette RawBased'] = lista3

lista4 = []
#Definición de 3ra Columna
for i in list(range(3)):
    lista4.append(dff.iloc[0,i+1])
    lista4.append(dff.iloc[1,i+1])
    lista4.append(dff.iloc[2,i+1])
    lista4.append(dff.iloc[3,i+1])
df1['Puntaje Silhouette FBased'] = lista4

lista4 = []
#Definición de 3ra Columna
for i in list(range(3)):
    lista4.append(df_f1.iloc[0,i+1])
    lista4.append(df_f1.iloc[1,i+1])
    lista4.append(df_f1.iloc[2,i+1])
    lista4.append(df_f1.iloc[3,i+1])
df1['Puntaje Silhouette FBased P1'] = lista4

lista4 = []
#Definición de 3ra Columna
for i in list(range(3)):
    lista4.append(df_f2.iloc[0,i+1])
    lista4.append(df_f2.iloc[1,i+1])
    lista4.append(df_f2.iloc[2,i+1])
    lista4.append(df_f2.iloc[3,i+1])
df1['Puntaje Silhouette FBased P2'] = lista4
#df1[['Algoritmo de agrupamiento', 'Métrica de similaridad', 'Puntaje Silhouette FBased', 'Puntaje Silhouette FBased P1', 'Puntaje Silhouette FBased P2']]
df1[['Algoritmo de agrupamiento', 'Métrica de similaridad', 'Puntaje Silhouette RawBased','Puntaje Silhouette FBased']]
# Out:
#    Algoritmo de agrupamiento Métrica de similaridad  \
# 0    Jerárquico Aglomerativo   Distancia Euclideana
# 1    Jerárquico Aglomerativo    Correlación Pearson
# 2    Jerárquico Aglomerativo   Correlación Spearman
# 3    Jerárquico Aglomerativo   Dynamic Time Warping
# 4                    K-means   Distancia Euclideana
# 5                    K-means    Correlación Pearson
# 6                    K-means   Correlación Spearman
# 7                    K-means   Dynamic Time Warping
# 8                     DBScan   Distancia Euclideana
# 9                     DBScan    Correlación Pearson
# 10                    DBScan   Correlación Spearman
# 11                    DBScan   Dynamic Time Warping
#
#     Puntaje Silhouette RawBased  Puntaje Silhouette FBased
# 0                      0.667898                   0.836977
# 1                      0.314454                   0.614693
# 2                      0.496461                   0.571987
# ...

# %%
df1= pd.DataFrame()
lista1 = []
lista2 = []
#Definición de 1ra Columna
for i in list(range(4)):
    lista1.append('Jerárquico Aglomerativo')
for i in list(range(4)):
    lista1.append('K-means')
for i in list(range(4)):
    lista1.append('DBScan')   
    
#Definición de 2da Columna
for i in list(range(3)):
    lista2.append('Distancia Euclideana')
    lista2.append('Correlación Pearson')
    lista2.append('Correlación Spearman')
    lista2.append('Dynamic Time Warping')

#Agrupamiento de columnas para la tabla
df1['Algoritmo de agrupamiento'] = lista1
df1['Métrica de similaridad'] = lista2

#Definición de 3ra Columna
lista4 = []
for i in list(range(3,6)):
    lista4.append(df.iloc[0,i+1])
    lista4.append(df.iloc[1,i+1])
    lista4.append(df.iloc[2,i+1])
    lista4.append(df.iloc[3,i+1])
df1['Puntaje CHZ RawBased'] = lista4

#Definición de 4ta Columna
lista5 = []
for i in list(range(3,6)):
    lista5.append(dff.iloc[0,i+1])
    lista5.append(dff.iloc[1,i+1])
    lista5.append(dff.iloc[2,i+1])
    lista5.append(dff.iloc[3,i+1])
df1['Puntaje CHZ FBased'] = lista5
df1
# Out:
#    Algoritmo de agrupamiento Métrica de similaridad  Puntaje CHZ RawBased  \
# 0    Jerárquico Aglomerativo   Distancia Euclideana           1013.780870
# 1    Jerárquico Aglomerativo    Correlación Pearson            145.381454
# 2    Jerárquico Aglomerativo   Correlación Spearman            239.488601
# 3    Jerárquico Aglomerativo   Dynamic Time Warping            788.946945
# 4                    K-means   Distancia Euclideana           1020.159559
# 5                    K-means    Correlación Pearson            167.310835
# 6                    K-means   Correlación Spearman            269.004503
# 7                    K-means   Dynamic Time Warping            832.699887
# 8                     DBScan   Distancia Euclideana            184.766121
# 9                     DBScan    Correlación Pearson             10.086778
# 10                    DBScan   Correlación Spearman             54.407344
# 11                    DBScan   Dynamic Time Warping              2.904499
#
# ...

# %%
df1= pd.DataFrame()
lista1 = []
lista2 = []
#Definición de 1ra Columna
for i in list(range(4)):
    lista1.append('Jerárquico Aglomerativo')
for i in list(range(4)):
    lista1.append('K-means')
for i in list(range(4)):
    lista1.append('DBScan')   
    
#Definición de 2da Columna
for i in list(range(3)):
    lista2.append('Distancia Euclideana')
    lista2.append('Correlación Pearson')
    lista2.append('Correlación Spearman')
    lista2.append('Dynamic Time Warping')

#Agrupamiento de columnas para la tabla
df1['Algoritmo de agrupamiento'] = lista1
df1['Métrica de similaridad'] = lista2

#Definición de 3ra Columna
lista5 = []
for i in list(range(6,9)):
    lista5.append(df.iloc[0,i+1])
    lista5.append(df.iloc[1,i+1])
    lista5.append(df.iloc[2,i+1])
    lista5.append(df.iloc[3,i+1])
df1['Puntaje DUNN RawBased'] = lista5

#Definición de 5ta Columna
lista4 = []
for i in list(range(6,9)):
    lista4.append(dff.iloc[0,i+1])
    lista4.append(dff.iloc[1,i+1])
    lista4.append(dff.iloc[2,i+1])
    lista4.append(dff.iloc[3,i+1])
df1['Puntaje DUNN FBased'] = lista4
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e51b978ac9b7> in <module>
#      24 lista5 = []
#      25 for i in list(range(6,9)):
# ---> 26     lista5.append(df.iloc[0,i+1])
#      27     lista5.append(df.iloc[1,i+1])
#      28     lista5.append(df.iloc[2,i+1])
#
# NameError: name 'df' is not defined

# %%
df1= pd.DataFrame()
lista1 = []
lista2 = []
#Definición de 1ra Columna
for i in list(range(4)):
    lista1.append('Jerárquico Aglomerativo')
for i in list(range(4)):
    lista1.append('K-means')
for i in list(range(4)):
    lista1.append('DBScan')   
    
#Definición de 2da Columna
for i in list(range(3)):
    lista2.append('Distancia Euclideana')
    lista2.append('Correlación Pearson')
    lista2.append('Correlación Spearman')
    lista2.append('Dynamic Time Warping')

#Agrupamiento de columnas para la tabla
df1['Algoritmo de agrupamiento'] = lista1
df1['Métrica de similaridad'] = lista2


#Definición de 3ra Columna
lista6 = []
for i in list(range(9,12)):
    lista6.append(df.iloc[0,i+1])
    lista6.append(df.iloc[1,i+1])
    lista6.append(df.iloc[2,i+1])
    lista6.append(df.iloc[3,i+1])
df1['Puntaje Davies RawBased'] = lista6

#Definición de 4ta Columna
lista5 = []
for i in list(range(9,12)):
    lista5.append(df.iloc[0,i+1])
    lista5.append(df.iloc[1,i+1])
    lista5.append(df.iloc[2,i+1])
    lista5.append(df.iloc[3,i+1])
df1['Puntaje Davies FBased'] = lista5
df1
# Out:
#    Algoritmo de agrupamiento Métrica de similaridad  Puntaje Davies RawBased  \
# 0    Jerárquico Aglomerativo   Distancia Euclideana                 0.505521
# 1    Jerárquico Aglomerativo    Correlación Pearson                 1.059217
# 2    Jerárquico Aglomerativo   Correlación Spearman                 0.598548
# 3    Jerárquico Aglomerativo   Dynamic Time Warping                 0.690141
# 4                    K-means   Distancia Euclideana                 0.498812
# 5                    K-means    Correlación Pearson                 1.028856
# 6                    K-means   Correlación Spearman                 0.618749
# 7                    K-means   Dynamic Time Warping                 0.686742
# 8                     DBScan   Distancia Euclideana                 1.065449
# 9                     DBScan    Correlación Pearson                 0.806673
# 10                    DBScan   Correlación Spearman                 0.583641
# ...
