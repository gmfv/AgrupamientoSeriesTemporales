# %% [markdown]
# # 8 atributos VS 10 atributos

# %%
import pandas as pd
import os

my_path = os.path.abspath('')
my_path = my_path.split('\\')
my_path_py = "\\".join(my_path[:-1])

# %%
F8_FS = pd.read_csv(my_path_py+'\\3_FeatureSelection\\Scores_FeatureSelection_F8K6.csv', sep=',')
# Out:
#                 Metrica  SIL HAC 8  SIL KM 8  SIL DB 8    CHZ HAC 8  \
# 0    Euclidean Distance   0.836977  0.863019  0.446337  2742.276480
# 1   Pearson Correlation   0.634458  0.657762  0.377648  1884.549681
# 2  Spearman Correlation   0.429535  0.452414  0.715602   154.506516
# 3  Dynamic Time Warping   0.827039  0.861064  0.387854  2699.420138
#
#       CHZ KM 8    CHZ DB 8  DAVIES HAC 8  DAVIES KM 8  DAVIES DB 8
# 0  3238.981584    9.566139      0.395113     0.331150     1.066877
# 1  2250.273034  485.212506      0.452866     0.464002     0.484933
# 2   160.698084   45.618818      0.905964     0.890570     1.007251
# 3  3164.967508   12.599769      0.348772     0.329848     1.198542

# %%
NewF = pd.read_csv(my_path_py+'\\4_NewFeatures\\ScoreswithNF_FeatureBased.csv', sep=',')
NewF = NewF.drop('Unnamed: 0', axis=1)
# Out:
#                 METRICA  SIL - HAC  SIL - KM  SIL - DB    CHZ - HAC  \
# 0    Euclidean Distance   0.831697  0.831697  0.078583  4839.708634
# 1   Pearson Correlation   0.618687  0.585444  0.522432  1643.981646
# 2  Spearman Correlation   0.397424  0.406032  0.340841   162.371878
# 3  Dynamic Time Warping   0.820651  0.820651 -0.247976  4670.389801
#
#       CHZ - KM    CHZ - DB  DUNN - HAC  DUNN - KM  DUNN - DB  DAVID - HAC  \
# 0  4839.708634    7.758089    0.784494   0.784494   0.002528     0.357976
# 1  1750.762344  514.401127    1.629828   1.629828   0.986151     0.527234
# 2   168.854225   72.505538    0.000000   0.000000   0.000000     0.855131
# 3  4670.389801    2.737649    0.818363   0.818363   0.001849     0.348938
#
#    DAVID - KM  DAVID - DB
# 0    0.357976    1.382688
# 1    0.528863    1.138387
# 2    0.852460    0.929641
# 3    0.348938    1.479328

# %% [markdown]
# # SILHOUETTE SCORE

# %%
compara = pd.DataFrame()
compara['Metrica'] = F8_FS['Metrica']

compara['HAC 8F'] = F8_FS['SIL HAC 8']
compara['HAC New Features'] = NewF['SIL - HAC'] 

compara['KM 8F'] = F8_FS['SIL KM 8']
compara['KM New Features'] = NewF['SIL - KM'] 

compara['DBS 8F'] = F8_FS['SIL DB 8']
compara['DBS New Features'] = NewF['SIL - DB'] 

compara
# Out:
#                 Metrica    HAC 8F  HAC New Features     KM 8F  \
# 0    Euclidean Distance  0.836977          0.831697  0.863019
# 1   Pearson Correlation  0.634458          0.618687  0.657762
# 2  Spearman Correlation  0.429535          0.397424  0.452414
# 3  Dynamic Time Warping  0.827039          0.820651  0.861064
#
#    KM New Features    DBS 8F  DBS New Features
# 0         0.831697  0.446337          0.078583
# 1         0.585444  0.377648          0.522432
# 2         0.406032  0.715602          0.340841
# 3         0.820651  0.387854         -0.247976

# %% [markdown]
# # CALINSKI HARAZS

# %%
compara2 = pd.DataFrame()
compara2['Metrica'] = F8_FS['Metrica']

compara2['HAC 8F'] = F8_FS['CHZ HAC 8']
compara2['HAC New Features'] = NewF['CHZ - HAC'] 

compara2['KM 8F'] = F8_FS['CHZ KM 8']
compara2['KM New Features'] = NewF['CHZ - KM'] 

compara2['DBS 8F'] = F8_FS['CHZ DB 8']
compara2['DBS New Features'] = NewF['CHZ - DB'] 


compara2
# Out:
#                 Metrica  HAC All Features       HAC 8F  KM All Features  \
# 0    Euclidean Distance       2228.435024  2742.276480      2612.301411
# 1   Pearson Correlation       1582.112815  1884.549681      1867.779633
# 2  Spearman Correlation        335.126053   154.506516       346.660645
# 3  Dynamic Time Warping       2202.816138  2699.420138      2574.902451
#
#          KM 8F  DBS All Features      DBS 8F
# 0  3238.981584          9.566139    9.566139
# 1  2250.273034          0.852401  485.212506
# 2   160.698084        185.222451   45.618818
# 3  3164.967508         11.921032   12.599769

# %%
compara3 = pd.DataFrame()
compara3['Metrica'] = F8_FS['Metrica']

compara3['HAC New Features'] = NewF['DAVID - HAC'] 
compara3['HAC 8F'] = F8_FS['DAVIES HAC 8']

compara3['KM New Features'] = NewF['DAVID - KM'] 
compara3['KM 8F'] = F8_FS['DAVIES KM 8']

compara3['DBS New Features'] = NewF['DAVID - DB'] 
compara3['DBS 8F'] = F8_FS['DAVIES DB 8']


compara3
# Out:
#                 Metrica  HAC All Features    HAC 8F  KM All Features  \
# 0    Euclidean Distance          0.392022  0.395113         0.310596
# 1   Pearson Correlation          0.477132  0.452866         0.472617
# 2  Spearman Correlation          0.559364  0.905964         0.762185
# 3  Dynamic Time Warping          0.392042  0.348772         0.319688
#
#       KM 8F  DBS All Features    DBS 8F
# 0  0.331150          1.066877  1.066877
# 1  0.464002          1.023568  0.484933
# 2  0.890570          0.377073  1.007251
# 3  0.329848          1.217600  1.198542
